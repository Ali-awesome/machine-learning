# %% [markdown]
# ### Importing packages and loading data.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./data.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %% [markdown]
# #### Making the data clean and consistant

# %%
df.columns = df.columns.str.lower().str.replace(' ','_')
col_str = list(df.dtypes[df.dtypes == 'object'].index)
col_str
for col in col_str:
    df[col] = df[col].str.lower().str.replace(' ','_')
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.hist(df.msrp,bins=100)
# Out:
# (array([3.480e+03, 5.618e+03, 1.580e+03, 4.230e+02, 2.060e+02, 1.110e+02,
#         7.600e+01, 5.600e+01, 4.100e+01, 7.000e+01, 6.100e+01, 3.100e+01,
#         2.500e+01, 2.600e+01, 2.500e+01, 1.600e+01, 8.000e+00, 7.000e+00,
#         5.000e+00, 8.000e+00, 6.000e+00, 9.000e+00, 5.000e+00, 8.000e+00,
#         3.000e+00, 1.000e+00, 2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([2.00000000e+03, 2.26390200e+04, 4.32780400e+04, 6.39170600e+04,
#         8.45560800e+04, 1.05195100e+05, 1.25834120e+05, 1.46473140e+05,
#         1.67112160e+05, 1.87751180e+05, 2.08390200e+05, 2.29029220e+05,
#         2.49668240e+05, 2.70307260e+05, 2.90946280e+05, 3.11585300e+05,
#         3.32224320e+05, 3.52863340e+05, 3.73502360e+05, 3.94141380e+05,
#         4.14780400e+05, 4.35419420e+05, 4.56058440e+05, 4.76697460e+05,
#         4.97336480e+05, 5.17975500e+05, 5.38614520e+05, 5.59253540e+05,
#         5.79892560e+05, 6.00531580e+05, 6.21170600e+05, 6.41809620e+05,
#         6.62448640e+05, 6.83087660e+05, 7.03726680e+05, 7.24365700e+05,
#         7.45004720e+05, 7.65643740e+05, 7.86282760e+05, 8.06921780e+05,
#         8.27560800e+05, 8.48199820e+05, 8.68838840e+05, 8.89477860e+05,
#         9.10116880e+05, 9.30755900e+05, 9.51394920e+05, 9.72033940e+05,
#         9.92672960e+05, 1.01331198e+06, 1.03395100e+06, 1.05459002e+06,
#         1.07522904e+06, 1.09586806e+06, 1.11650708e+06, 1.13714610e+06,
#         1.15778512e+06, 1.17842414e+06, 1.19906316e+06, 1.21970218e+06,
#         1.24034120e+06, 1.26098022e+06, 1.28161924e+06, 1.30225826e+06,
#         1.32289728e+06, 1.34353630e+06, 1.36417532e+06, 1.38481434e+06,
#         1.40545336e+06, 1.42609238e+06, 1.44673140e+06, 1.46737042e+06,
#         1.48800944e+06, 1.50864846e+06, 1.52928748e+06, 1.54992650e+06,
#         1.57056552e+06, 1.59120454e+06, 1.61184356e+06, 1.63248258e+06,
#         1.65312160e+06, 1.67376062e+06, 1.69439964e+06, 1.71503866e+06,
#         1.73567768e+06, 1.75631670e+06, 1.77695572e+06, 1.79759474e+06,
#         1.81823376e+06, 1.83887278e+06, 1.85951180e+06, 1.88015082e+06,
#         1.90078984e+06, 1.92142886e+06, 1.94206788e+06, 1.96270690e+06,
#         1.98334592e+06, 2.00398494e+06, 2.02462396e+06, 2.04526298e+06,
#         2.06590200e+06]),
#  <BarContainer object of 100 artists>)
